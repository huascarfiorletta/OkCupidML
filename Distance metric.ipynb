# %%
import pandas as pd
import numpy as np

#load questions csv
questions_data = pd.read_csv('question_data.csv',header=0,delimiter=';' )
questions_data = questions_data.rename(columns={questions_data.columns[0]: "q" })
#keep only question lines
questions_data = questions_data[questions_data.q.str[0] == 'q']
questions_data
# Out:
#             q                                               text  \
# 0          q2                                   Breast implants?
# 1         q11  How does the idea of being slapped hard in the...
# 2         q12  Divide your age by 2.  Have you had sex with a...
# 3         q13  Is a girl who's slept with 100 guys a bad person?
# 4         q14  Is a guy who's slept with 100 girls a bad person?
# 5         q16  Should sex with someone 16 years old be a jail...
# 6         q17           Would you date someone just for the sex?
# 7         q18  Do you have experience being in a slave/master...
# 8         q20  BDSM: Without looking it up, do you know exact...
# 9         q21                      Do you enjoy meaningless sex?
# 10        q22                        Do you read erotic fiction?
# 11        q24  Is it wrong to watch pornographic films if you...
# 12        q25  Would you watch a porno movie with your ideal ...
# ...

# %%
def user_similarity(user_1, user_2, questions_list):
    result = 0.0
    #account for unknown by limiting max and min match scores
    #account for complementary answers e.g. q29, blacklist them for now
    #different rating for categorical vs ordinal
    return result 

orig_data = pd.read_pickle("./unprocessed.bz2")
list(orig_data)
# Out:
#                             q2          q11  q12  q13  q14  q16  q17  q18  \
# 0                          NaN    Horrified  NaN  NaN  NaN  NaN   No  NaN
# 1                          NaN          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2                          NaN          NaN  NaN   No   No  NaN   No  NaN
# 3                          NaN          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4                          NaN          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 5                          NaN          NaN   No   No   No   No  NaN  NaN
# 6                          NaN  Indifferent  NaN   No   No  NaN  NaN  NaN
# 7                          NaN          NaN  NaN   No   No  NaN  NaN  NaN
# 8                          NaN          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 9                          NaN          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 10     more pathetic than cool    Horrified   No   No   No  NaN   No  NaN
# 11                         NaN          NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...
