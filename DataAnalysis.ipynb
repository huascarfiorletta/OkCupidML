# %%
import pandas as pd
import numpy as np

#load data
orig_data = pd.read_pickle("./unprocessed.bz2")
#keep only 2 columns
# small_data = orig_data[['gender_orientation',"q12719","q9688"]].copy()
# small_data = small_data.replace(np.nan, 'Nan', regex=True)
question_headers = []
non_question_headers = []
for h in list(orig_data):
    if h[0] == 'q':
        question_headers.append(h)
    elif h[0] != 'p':
        non_question_headers.append(h)
print '\',\''.join(non_question_headers)

print 'Number of questions', len(question_headers)
# Out:
# d_astrology_seriosity','d_education_phase','d_gender','d_income','d_religion_type','d_drugs','lf_want','d_smokes','d_astrology_sign','d_country','d_drinks','d_age','d_ethnicity','d_offspring_current','d_bodytype','lf_max_age','lf_for','d_job','d_orientation','d_languages','d_relationship','d_offspring_desires','lf_location','lf_min_age','d_education_type','lf_single','d_religion_seriosity','CA','gender_orientation','gender','race','gender2','gender2_num','CA_items
# Number of questions 2541

# %%
question_data = orig_data[question_headers]
# print question_data.count
question_data.isnull().mean().mean()
# Out:
# 0.7764702925782638

# %%
for title in list(orig_data):
    vc = orig_data[title].value_counts()
    total = vc.sum()
    if total > 54000 :
        print vc, '\n', total,'\n\n'
# Out:
# Not at all important    25227
# Not very important      12456
# Somewhat important      11504
# Extremely important      4953
# Name: q41, dtype: int64
# 54140
#
#
# No     37750
# Yes    16693
# Name: q325, dtype: int64
# 54443
#
#
# No     38161
# Yes    18962
# Name: q501, dtype: int64
# 57123
#
#
# Both       23133
# Dogs       19883
# Cats        7674
# Neither     4056
# Name: q997, dtype: int64
# 54746
#
#
# Yes, but only soft stuff like marijuana    26443
# No                                         22062
# Yes                                         7192
# Name: q9688, dtype: int64
# 55697
#
#
# Totally willing!                            46226
# Hesitant, but I'd certainly consider it.    11640
# I'm not interested in meeting in person.      177
# Name: q16053, dtype: int64
# 58043
#
#
# Never - Get a job                 37271
# It's okay, if it is not abused    18029
# No problem                         9395
# Okay for short amounts of time     3676
# Name: q34113, dtype: int64
# 68371
#
#
# Yes    34020
# No     20944
# Name: q44639, dtype: int64
# 54964
#
#
# No     49627
# Yes     6016
# Name: q60100, dtype: int64
# 55643
#
#
# I don't really care.    67395
# Yes.                      830
# No.                       146
# Name: q64664, dtype: int64
# 68371
#
#
# Rosé (such as White Zinfindel).            51170
# Red (such as Merlot, Cabernet, Shiraz).     7888
# I don't drink wine.                         5027
# White (such as Chardonnay, Riesling).       4286
# Name: q85419, dtype: int64
# 68371
#
#
# No     49490
# Yes     4712
# Name: q179268, dtype: int64
# 54202
#
#
# Yes    28340
# No     27355
# Name: q358077, dtype: int64
# 55695
#
#
# Yes    52106
# No      2590
# Name: q358084, dtype: int64
# 54696
#
#
# Can't answer without a subtitle    49364
# Yes                                15496
# No                                  3511
# Name: q416235, dtype: int64
# 68371
#
#
# Man                                                                 40215
# Woman                                                               25952
# Cis Man                                                                19
# Cis Woman                                                              18
# Trans Woman                                                             7
# Genderqueer                                                             7
# Woman, Cis Woman                                                        7
# Man, Cis Man                                                            6
# Genderfluid                                                             6
# Cis Man, Man                                                            5
# Non-binary                                                              5
# Genderqueer, Non-binary                                                 4
# Cis Woman, Woman                                                        4
# Man, Genderfluid                                                        4
# Other                                                                   4
# Agender                                                                 3
# Woman, Transgender                                                      3
# Woman, Trans Woman                                                      2
# Woman, Genderqueer                                                      2
# Genderqueer, Woman                                                      2
# Gender Nonconforming, Man                                               2
# Gender Nonconforming, Cis Man                                           2
# Gender Nonconforming                                                    2
# Woman, Intersex                                                         1
# Genderqueer, Transfeminine, Androgynous, Man                            1
# Gender Nonconforming, Agender                                           1
# Transgender, Trans Man, Transmasculine                                  1
# Genderfluid, Non-binary, Woman, Man                                     1
# Genderfluid, Genderqueer, Pangender                                     1
# Trans Man                                                               1
#                                                                     ...
# Non-binary, Transgender, Transsexual, Trans Woman, Genderqueer          1
# Androgynous, Genderqueer                                                1
# Androgynous                                                             1
# Agender, Non-binary, Other                                              1
# Genderfluid, Cis Man, Genderqueer                                       1
# Transgender, Transfeminine, Non-binary, Genderfluid, Androgynous        1
# Transgender, Agender, Other                                             1
# Man, Non-binary, Gender Nonconforming, Other                            1
# Woman, Trans Woman, Transgender, Transsexual                            1
# Trans Woman, Transgender, Genderqueer                                   1
# Man, Trans Man, Transmasculine                                          1
# Man, Cis Man, Androgynous                                               1
# Man, Genderfluid, Genderqueer, Non-binary                               1
# Trans Woman, Transgender                                                1
# Non-binary, Other, Woman                                                1
# Intersex                                                                1
# Cis Man, Two Spirit                                                     1
# Genderqueer, Transgender, Transfeminine, Trans Woman, Woman             1
# Genderqueer, Non-binary, Transgender, Woman                             1
# Genderqueer, Non-binary, Woman, Other                                   1
# Bigender, Cis Woman, Woman                                              1
# Transgender, Trans Man                                                  1
# Genderqueer, Gender Nonconforming, Genderfluid                          1
# Non-binary, Cis Woman                                                   1
# Agender, Genderqueer                                                    1
# Transgender, Genderfluid, Trans Woman                                   1
# Androgynous, Trans Woman                                                1
# Woman, Other                                                            1
# Man, Agender, Gender Nonconforming, Non-binary, Other                   1
# Non-binary, Genderqueer, Androgynous                                    1
# Name: d_gender, Length: 107, dtype: int64
# 66365
#
#
# -               24567
# Atheism          9794
# Christianity     9274
# Agnosticism      8314
# Other            6193
# Catholicism      4829
# Judaism          1683
# Buddhism          999
# Hinduism          366
# Islam             345
# Name: d_religion_type, dtype: int64
# 66364
#
#
# Never        50218
# Sometimes     5086
# Often          393
# Name: d_drugs, dtype: int64
# 55697
#
#
# Women                    37011
# Men                      17534
# Everyone                  5130
# Men who like women        4465
# Women who like men         632
# Straight men only          559
# All who like bi women      445
# Everybody                  440
# Men who like men            48
# Straight women only         32
# Women who like women        32
# All who like bi men         14
# Gay men only                 9
# Bi women only                8
# Gay women only               5
# Bi men and women             1
# Name: lf_want, dtype: int64
# 66365
#
#
# No                40999
# Yes                4448
# Sometimes          4095
# When drinking      2884
# Trying to quit     2664
# Name: d_smokes, dtype: int64
# 55090
#
#
# -              16961
# Leo             4549
# Cancer          4357
# Scorpio         4317
# Gemini          4263
# Virgo           4237
# Taurus          4185
# Libra           4164
# Aries           3980
# Aquarius        3980
# Pisces          3907
# Sagittarius     3858
# Capricorn       3606
# Name: d_astrology_sign, dtype: int64
# 66364
#
#
# UK                                   8438
# NY                                   7989
# CA                                   7145
# TX                                   2767
# FL                                   1760
# Australia                            1678
# NJ                                   1662
# IL                                   1559
# PA                                   1533
# WA                                   1391
# MA                                   1344
# LA                                   1336
# Ontario                              1059
# OH                                   1048
# Germany                              1021
# VA                                    967
# MI                                    961
# Netherlands                           904
# GA                                    895
# OR                                    877
# Denmark                               868
# NC                                    835
# CO                                    779
# MD                                    779
# MN                                    713
# AZ                                    670
# Italy                                 656
# WI                                    581
# IN                                    578
# Singapore                             547
#                                      ...
# Prince Edward Island                    2
# Macau                                   2
# Mauritius                               1
# Lesotho                                 1
# 13                                      1
# Isle of Man                             1
# Afghanistan                             1
# Falkland Islands (Islas Malvinas)       1
# Ghana                                   1
# Uzbekistan                              1
# Guernsey                                1
# El Salvador                             1
# Republic of the Congo                   1
# Vanuatu                                 1
# Niue                                    1
# Cayman Islands                          1
# Mongolia                                1
# Albania                                 1
# Namibia                                 1
# Myanmar                                 1
# South Georgia and the Islands           1
# Tajikistan                              1
# Svalbard                                1
# Tanzania                                1
# Antigua and Barbuda                     1
# Belize                                  1
# Mali                                    1
# Paraguay                                1
# Liberia                                 1
# Laos                                    1
# Name: d_country, Length: 202, dtype: int64
# 66365
#
#
# Socially       38240
# Rarely          8808
# Often           4572
# Not at all      4408
# Very often       509
# Desperately      299
# Name: d_drinks, dtype: int64
# 56836
# 27.0     3861
# 29.0     3793
# 26.0     3742
# 30.0     3688
# 28.0     3621
# 25.0     3495
# 31.0     3389
# 24.0     3354
# 32.0     3212
# 34.0     3010
# 33.0     2989
# 35.0     2703
# 36.0     2262
# 23.0     2222
# 37.0     2009
# 22.0     1826
# 38.0     1710
# 39.0     1512
# 40.0     1401
# 21.0     1373
# 41.0     1166
# 42.0     1081
# 20.0     1060
# 44.0      961
# 43.0      937
# 19.0      841
# 45.0      840
# 46.0      607
# 18.0      596
# 47.0      470
#          ...
# 58.0       52
# 60.0       41
# 61.0       30
# 62.0       20
# 63.0       19
# 64.0       17
# 65.0       13
# 67.0       13
# 68.0       10
# 66.0        7
# 69.0        5
# 70.0        5
# 71.0        4
# 98.0        3
# 91.0        3
# 74.0        2
# 94.0        2
# 95.0        2
# 75.0        2
# 72.0        2
# 100.0       2
# 86.0        1
# 76.0        1
# 84.0        1
# 99.0        1
# 81.0        1
# 77.0        1
# 97.0        1
# 90.0        1
# 78.0        1
# Name: d_age, Length: 71, dtype: int64
# 66365
#
#
# White                                                                                                      38599
# Asian                                                                                                       3187
# Hispanic / Latin                                                                                            2802
# Black                                                                                                       2702
# Other                                                                                                       1793
# Hispanic / Latin, White                                                                                      905
# Indian                                                                                                       723
# White, Other                                                                                                 548
# Native American, White                                                                                       460
# Middle Eastern                                                                                               392
# Asian, White                                                                                                 322
# Black, White                                                                                                 264
# Middle Eastern, White                                                                                        191
# Black, Other                                                                                                 165
# Native American                                                                                              139
# Black, Hispanic / Latin                                                                                      137
# Pacific Islander                                                                                             129
# Black, Native American                                                                                       106
# Asian, Pacific Islander                                                                                       99
# Hispanic / Latin, Other                                                                                       96
# Asian, Other                                                                                                  95
# Hispanic / Latin, White, Other                                                                                91
# Asian, Middle Eastern, Black, Native American, Indian, Pacific Islander, Hispanic / Latin, White, Other       82
# Black, Native American, White                                                                                 80
# Native American, White, Other                                                                                 79
# Asian, Indian                                                                                                 77
# Pacific Islander, White                                                                                       57
# Native American, Hispanic / Latin, White                                                                      56
# Asian, Hispanic / Latin                                                                                       50
# Native American, Hispanic / Latin                                                                             45
#                                                                                                            ...
# Asian, Middle Eastern, Black, Indian                                                                           1
# Asian, Middle Eastern, Indian, Hispanic / Latin, Other                                                         1
# Asian, Native American, Pacific Islander, Hispanic / Latin                                                     1
# Middle Eastern, Native American, Indian, White                                                                 1
# Middle Eastern, Black, Indian, Hispanic / Latin, White                                                         1
# Asian, Black, Native American, Indian                                                                          1
# Black, Indian, Pacific Islander, Hispanic / Latin                                                              1
# Middle Eastern, Indian, White                                                                                  1
# Middle Eastern, Native American, White, Other                                                                  1
# Asian, Black, Pacific Islander, Hispanic / Latin, White, Other                                                 1
# Asian, Middle Eastern, Native American, Indian, Hispanic / Latin, White, Other                                 1
# Asian, Middle Eastern, Black, Native American, Indian, Pacific Islander                                        1
# Middle Eastern, Native American, Other                                                                         1
# Middle Eastern, Black, Native American, Hispanic / Latin, White                                                1
# Middle Eastern, Indian, Other                                                                                  1
# Middle Eastern, Black, Native American, Hispanic / Latin, White, Other                                         1
# Black, Native American, Pacific Islander                                                                       1
# Asian, Native American, Indian, Pacific Islander                                                               1
# Indian, Hispanic / Latin, White                                                                                1
# Asian, Middle Eastern, Pacific Islander, Hispanic / Latin, White                                               1
# Asian, Middle Eastern, Black, Native American, Indian, Pacific Islander, Hispanic / Latin, Other               1
# Asian, Middle Eastern, Black, Native American, Indian, Pacific Islander, Hispanic / Latin                      1
# Black, Native American, Pacific Islander, Hispanic / Latin, White                                              1
# Asian, Middle Eastern, Native American, Indian, White                                                          1
# Native American, Indian, Hispanic / Latin, White                                                               1
# Asian, Middle Eastern, Native American, Indian, Pacific Islander, Hispanic / Latin, White, Other               1
# Asian, Middle Eastern, Native American                                                                         1
# Middle Eastern, Indian, White, Other                                                                           1
# Asian, Native American, Indian, Hispanic / Latin, White                                                        1
# Asian, Black, Indian, White                                                                                    1
# Name: d_ethnicity, Length: 211, dtype: int64
# 55424
#
#
# Average           18272
# Athletic           8167
# Fit                8121
# A little extra     5016
# Curvy              4925
# Thin               4315
# Full figured       1941
# Overweight         1790
# Skinny             1498
# Used up             351
# Jacked              307
# Rather not say      194
# Name: d_bodytype, dtype: int64
# 54897
#
#
# 35.0    8930
# 40.0    8073
# 45.0    4889
# 36.0    4372
# 38.0    4349
# 34.0    4189
# 50.0    2848
# 42.0    2698
# 30.0    2331
# 37.0    1788
# 26.0    1703
# 44.0    1674
# 32.0    1474
# 48.0    1418
# 39.0    1407
# 46.0    1341
# 28.0    1141
# 99.0    1081
# 55.0     991
# 43.0     919
# 60.0     692
# 52.0     633
# 41.0     567
# 47.0     531
# 54.0     502
# 33.0     479
# 25.0     464
# 49.0     422
# 27.0     336
# 56.0     336
#         ...
# 90.0      68
# 84.0      60
# 78.0      58
# 20.0      55
# 88.0      53
# 82.0      52
# 59.0      50
# 21.0      49
# 94.0      45
# 86.0      44
# 96.0      37
# 92.0      35
# 69.0      31
# 75.0      30
# 61.0      27
# 63.0      23
# 67.0      11
# 98.0      10
# 81.0       3
# 97.0       3
# 77.0       3
# 85.0       3
# 95.0       2
# 91.0       2
# 87.0       2
# 79.0       2
# 89.0       2
# 83.0       1
# 93.0       1
# 73.0       1
# Name: lf_max_age, Length: 80, dtype: int64
# 66365
#
#
# For  new friends, long-term dating, short-term dating                24542
# For  new friends                                                     14803
# For  new friends, long-term dating                                    8300
# For  new friends, long-term dating, short-term dating, casual sex     5813
# For  long-term dating, short-term dating                              4520
# For  long-term dating                                                 3233
# For  new friends, short-term dating                                   1496
# For  new friends, short-term dating, casual sex                       1168
# For  long-term dating, short-term dating, casual sex                   787
# For  new friends, casual sex                                           470
# For  short-term dating                                                 399
# For  new friends, long-term dating, casual sex                         316
# For  casual sex                                                        255
# For  short-term dating, casual sex                                     203
# For  long-term dating, casual sex                                       60
# Name: lf_for, dtype: int64
# 66365
#
#
# Straight                                               57774
# Bisexual                                                4769
# Gay                                                     3401
# Queer                                                     50
# Pansexual                                                 31
# Heteroflexible                                            29
# Straight, Sapiosexual                                     29
# Queer, Bisexual                                            9
# Sapiosexual                                                8
# Asexual                                                    8
# Bisexual, Queer                                            8
# Heteroflexible, Sapiosexual                                8
# Sapiosexual, Straight                                      8
# Straight, Demisexual                                       7
# Pansexual, Sapiosexual                                     7
# Straight, Heteroflexible                                   7
# Demisexual                                                 6
# Bisexual, Sapiosexual                                      6
# Lesbian                                                    6
# Questioning                                                5
# Heteroflexible, Bisexual                                   4
# Pansexual, Demisexual                                      4
# Straight, Demisexual, Sapiosexual                          4
# Pansexual, Queer, Sapiosexual                              4
# Pansexual, Queer                                           4
# Gay, Queer                                                 4
# Pansexual, Bisexual                                        4
# Queer, Pansexual, Sapiosexual                              4
# Bisexual, Queer, Sapiosexual                               3
# Queer, Bisexual, Pansexual                                 3
#                                                        ...
# Pansexual, Bisexual, Lesbian, Straight, Gay                1
# Pansexual, Queer, Asexual, Demisexual                      1
# Bisexual, Demisexual                                       1
# Queer, Pansexual, Bisexual, Gay                            1
# Queer, Pansexual, Sapiosexual, Bisexual                    1
# Heteroflexible, Sapiosexual, Pansexual, Queer              1
# Homoflexible                                               1
# Queer, Sapiosexual, Lesbian, Bisexual                      1
# Bisexual, Pansexual, Asexual, Straight, Queer              1
# Queer, Sapiosexual                                         1
# Pansexual, Bisexual, Heteroflexible                        1
# Sapiosexual, Homoflexible, Bisexual, Lesbian, Queer        1
# Demisexual, Questioning                                    1
# Bisexual, Asexual, Demisexual                              1
# Bisexual, Queer, Pansexual                                 1
# Sapiosexual, Bisexual, Queer, Pansexual                    1
# Queer, Homoflexible, Lesbian                               1
# Heteroflexible, Sapiosexual, Pansexual                     1
# Sapiosexual, Pansexual, Heteroflexible, Queer              1
# Queer, Homoflexible, Sapiosexual                           1
# Straight, Queer, Pansexual                                 1
# Sapiosexual, Demisexual                                    1
# Gay, Homoflexible, Queer                                   1
# Pansexual, Sapiosexual, Bisexual                           1
# Gay, Homoflexible, Queer, Lesbian                          1
# Straight, Sapiosexual, Questioning                         1
# Homoflexible, Heteroflexible, Pansexual, Bisexual          1
# Queer, Gay                                                 1
# Straight, Sapiosexual, Asexual                             1
# Heteroflexible, Demisexual, Bisexual, Asexual              1
# Name: d_orientation, Length: 160, dtype: int64
# 66365
#
#
# English                                                                                         31226
# English (Fluently)                                                                               7195
# English (Fluently), Spanish (Poorly)                                                             1743
# English (Fluently), Spanish (Okay)                                                               1183
# English (Fluently), Spanish (Fluently)                                                            972
# English (Fluently), French (Poorly)                                                               796
# English, Spanish                                                                                  519
# English (Fluently), French (Okay)                                                                 504
# English (Fluently), German (Poorly)                                                               434
# English (Okay)                                                                                    350
# English, Spanish (Poorly)                                                                         275
# English (Fluently), French (Fluently)                                                             269
# English (Fluently), German (Fluently)                                                             241
# English, Spanish (Okay)                                                                           241
# English (Poorly)                                                                                  236
# English (Fluently), Chinese (Fluently)                                                            230
# English (Fluently), Japanese (Poorly)                                                             207
# English (Fluently), German (Okay)                                                                 183
# English, French                                                                                   182
# English, French (Poorly)                                                                          181
# English, Chinese                                                                                  179
# English (Fluently), Chinese (Okay)                                                                141
# English, French (Okay)                                                                            131
# English (Fluently), Other (Fluently)                                                              121
# English (Fluently), Dutch (Fluently)                                                              120
# English (Fluently), French (Poorly), Spanish (Poorly)                                             120
# English (Fluently), Italian (Poorly)                                                              113
# English (Fluently), Hebrew (Fluently)                                                             108
# English (Fluently), Sign Language (Okay)                                                          107
# English (Fluently), Sign Language (Poorly)                                                        107
#                                                                                                 ...
# English (Fluently), Spanish (Okay), Hindi (Fluently), Other (Fluently)                              1
# English (Fluently), Hebrew (Okay), French (Okay), Persian (Okay), Arabic (Poorly)                   1
# English (Poorly), Irish (Okay), German (Okay)                                                       1
# English, German, Chinese                                                                            1
# English (Fluently), Spanish (Okay), Korean (Poorly), Chinese (Poorly)                               1
# English, C++, LISP, Spanish (Fluently), Other                                                       1
# English (Fluently), German (Fluently), Spanish (Fluently), Portuguese (Okay)                        1
# English, Korean, Spanish                                                                            1
# English (Fluently), Other (Okay), Welsh (Poorly), German (Okay)                                     1
# English (Okay), Sign Language (Poorly), C++ (Poorly)                                                1
# English (Fluently), Bulgarian (Fluently), Russian (Fluently)                                        1
# English, Other (Fluently), French (Poorly)                                                          1
# English (Fluently), Italian (Okay), Spanish (Fluently), Portuguese (Okay)                           1
# English (Fluently), Italian (Poorly), Sign Language (Poorly), Latin (Poorly)                        1
# English, Norwegian, Albanian, Other                                                                 1
# English (Poorly), Afrikaans (Fluently), Danish (Fluently)                                           1
# English (Fluently), Spanish (Fluently), French (Okay), German (Okay), Chinese (Okay)                1
# English (Fluently), Yiddish (Fluently)                                                              1
# English (Fluently), Spanish (Fluently), Latin (Poorly)                                              1
# English (Fluently), Spanish (Fluently), Portuguese (Okay), Russian (Poorly), French (Poorly)        1
# English, Esperanto, Hebrew, Ancient Greek, Japanese                                                 1
# English, Spanish (Okay), French (Poorly), Arabic (Poorly), Urdu (Poorly)                            1
# English (Fluently), Cebuano (Fluently), Tagalog (Fluently)                                          1
# English (Fluently), Dutch (Fluently), Arabic (Poorly), French (Okay), Spanish (Okay)                1
# English (Fluently), Polish (Poorly), French (Poorly)                                                1
# English (Fluently), German (Fluently), Italian (Fluently), French (Okay), Greek (Poorly)            1
# English (Fluently), Greek (Poorly), Hawaiian (Poorly), Sign Language (Okay), Spanish (Okay)         1
# English, French, Spanish, Hebrew, Arabic                                                            1
# English (Fluently), Finnish (Fluently), French (Poorly), Swedish (Poorly), German (Poorly)          1
# English, Turkish, Spanish (Poorly)                                                                  1
# Name: d_languages, Length: 8121, dtype: int64
# 66352
#
#
# Single               65586
# Seeing Someone         396
# Open relationship      329
# Married                 51
# Available                2
# Unknown                  1
# Name: d_relationship, dtype: int64
# 66365
#
#
# Near me             56938
# Located anywhere     9427
# Name: lf_location, dtype: int64
# 66365
#
#
# 18.0    10928
# 25.0     7578
# 21.0     5663
# 20.0     5526
# 30.0     4704
# 24.0     4553
# 28.0     3854
# 22.0     3823
# 23.0     3754
# 19.0     3587
# 27.0     3195
# 26.0     3122
# 29.0     1810
# 32.0     1319
# 33.0      953
# 34.0      947
# 31.0      697
# 35.0      133
# 38.0       46
# 40.0       45
# 36.0       31
# 37.0       26
# 39.0       14
# 45.0       11
# 42.0        9
# 48.0        7
# 50.0        7
# 49.0        4
# 44.0        4
# 55.0        4
# 46.0        2
# 43.0        2
# 60.0        2
# 47.0        2
# 41.0        1
# 58.0        1
# 53.0        1
# Name: lf_min_age, dtype: int64
# 66365
#
#
# Who are single    66365
# Name: lf_single, dtype: int64
# 66365
# The best?  Maybe...    57236
# Absolutely.             6428
# No way.                 4707
# Name: q20062, dtype: int64
# 68371
#
#
# -0.052395    1352
#  0.702989    1247
# -1.586541    1202
# -0.802111    1021
#  0.189604    1000
# -0.786778     698
# -1.736796     612
# -0.041197     569
# -1.289137     524
# -0.395067     519
#  1.964930     489
# -0.665651     474
# -0.598015     452
# -0.969928     407
# -0.271835     407
#  0.763080     406
# -0.638505     363
#  1.223592     340
# -2.110129     339
# -1.139603     331
#  0.835388     325
#  0.684201     306
# -0.257632     287
#  1.795776     275
#  0.618663     268
# -0.018510     266
# -0.116749     261
#  0.364598     258
#  1.266567     251
#  0.741622     248
#              ...
#  0.433231       1
# -0.409076       1
#  0.767324       1
#  1.029757       1
# -1.267320       1
#  0.228813       1
# -1.130805       1
#  1.346609       1
#  0.516301       1
#  0.122289       1
#  0.826894       1
# -0.375724       1
# -1.230064       1
# -2.185322       1
# -0.865408       1
#  0.361056       1
# -1.005974       1
# -0.501752       1
#  0.056017       1
# -1.220559       1
# -0.188821       1
# -0.809399       1
#  0.137280       1
#  0.449525       1
# -1.963110       1
#  0.359656       1
#  1.027058       1
#  0.334418       1
#  1.251902       1
#  0.549587       1
# Name: CA, Length: 13332, dtype: int64
# 56598
#
#
# Hetero_male        36763
# Hetero_female      20984
# Bisexual_female     3793
# Gay_male            2384
# Gay_female          1008
# Bisexual_male        950
# Name: gender_orientation, dtype: int64
# 65882
#
#
# Man      40215
# Woman    25952
# Other      198
# Name: gender, dtype: int64
# 66365
#
#
# White               38599
# Mixed                4958
# Asian                3187
# Hispanic / Latin     2802
# Black                2702
# Other                1793
# Indian                723
# Middle Eastern        392
# Native American       139
# Pacific Islander      129
# Name: race, dtype: int64
# 55424
#
#
# Man      40215
# Woman    25952
# Name: gender2, dtype: int64
# 66167
#
#
# 1.0    40215
# 0.0    25952
# Name: gender2_num, dtype: int64
# 66167
#
#
# 0.0     13948
# 2.0      7294
# 1.0      7175
# 3.0      7059
# 4.0      6591
# 5.0      5643
# 6.0      4823
# 7.0      4506
# 8.0      3950
# 9.0      2950
# 10.0     2040
# 11.0     1335
# 12.0      659
# 13.0      303
# 14.0       95
# Name: CA_items, dtype: int64
# 68371

# %%
import seaborn as sns
import matplotlib.pyplot as plt
def plot_feat_crosstab(q_rows,q_colum,column_order=None,row_order=None,annot=True):
    no_na_data = orig_data.dropna(subset=[q_rows])
    cross_data = pd.crosstab(index = no_na_data[q_rows],columns= no_na_data[q_colum])
    if column_order:
        cross_data = cross_data.reindex(column_order, axis=1)
    if row_order:
        cross_data = cross_data.reindex(row_order, axis=0)
    #normalize by column
    norm_cross_data = cross_data.apply(lambda x: x/x.sum(), axis=0)
    norm_cross_data
    sns.heatmap(norm_cross_data, annot=annot)

#plot tattoos to income q128 / 'd_income'
print orig_data[q_rows].value_counts()
plt.figure(figsize = (16,5))
column_order = ['Less than $20,000','$20,000-$30,000','$30,000-$40,000','$40,000-$50,000','$50,000-$60,000','$60,000-$70,000','$70,000-$80,000','$80,000-$100,000','$100,000-$150,000','$150,000-$250,000','$250,000-$500,000','$500,000-$1,000,000','More than $1,000,000','Rather not say']
row_order = ['I have no tattoos','I have 1 or more LITTLE tattoos','I have 1 or more BIG tattoos']
plot_feat_crosstab('q128','d_income',column_order,row_order)
# Out:
# I have no tattoos                  25807
# I have 1 or more LITTLE tattoos     8379
# I have 1 or more BIG tattoos        6264
# Name: q128, dtype: int64

# %%
#Drugs to age d_drugs / d_age -> drug usage peaks at 21 and then diminishes
plt.figure(figsize = (32,5))
plot_feat_crosstab('d_drugs','d_age',None,None,annot=False)
